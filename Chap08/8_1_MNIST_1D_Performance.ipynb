# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
# !mkdir ./sample_data

args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 50   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
  torch.nn.Linear(D_i, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_o),
)

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if type(layer_in) == nn.Linear:
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=50, out_features=50, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.709436, train error 68.05,  test loss 1.728224, test error 70.70
# Epoch     1, train loss 1.509834, train error 59.42,  test loss 1.570079, test error 62.50
# Epoch     2, train loss 1.335588, train error 49.17,  test loss 1.435577, test error 57.30
# Epoch     3, train loss 1.243971, train error 48.85,  test loss 1.364470, test error 54.90
# Epoch     4, train loss 1.120803, train error 42.33,  test loss 1.290385, test error 50.80
# Epoch     5, train loss 1.044213, train error 39.28,  test loss 1.292720, test error 52.00
# Epoch     6, train loss 0.925775, train error 34.53,  test loss 1.192217, test error 46.60
# Epoch     7, train loss 0.906677, train error 34.40,  test loss 1.237670, test error 47.10
# Epoch     8, train loss 0.851187, train error 32.68,  test loss 1.238462, test error 47.10
# Epoch     9, train loss 0.779018, train error 30.22,  test loss 1.225895, test error 45.00
# Epoch    10, train loss 0.652766, train error 23.68,  test loss 1.159577, test error 43.90
# Epoch    11, train loss 0.618608, train error 23.22,  test loss 1.193124, test error 42.40
# Epoch    12, train loss 0.589347, train error 21.62,  test loss 1.178770, test error 42.40
# Epoch    13, train loss 0.564827, train error 21.30,  test loss 1.229017, test error 44.20
# Epoch    14, train loss 0.522912, train error 18.85,  test loss 1.200457, test error 43.60
# Epoch    15, train loss 0.490438, train error 17.70,  test loss 1.231574, test error 42.50
# Epoch    16, train loss 0.453195, train error 16.60,  test loss 1.230815, test error 42.50
# Epoch    17, train loss 0.447592, train error 16.03,  test loss 1.277001, test error 42.20
# Epoch    18, train loss 0.445714, train error 16.60,  test loss 1.328906, test error 43.90
# Epoch    19, train loss 0.415391, train error 15.10,  test loss 1.315661, test error 42.70
# Epoch    20, train loss 0.340174, train error 11.18,  test loss 1.272360, test error 41.70
# Epoch    21, train loss 0.322975, train error 10.57,  test loss 1.319272, test error 42.60
# Epoch    22, train loss 0.307003, train error 9.72,  test loss 1.348437, test error 42.20
# Epoch    23, train loss 0.294370, train error 9.32,  test loss 1.359756, test error 41.50
# Epoch    24, train loss 0.289097, train error 9.68,  test loss 1.399266, test error 42.10
# Epoch    25, train loss 0.269992, train error 7.95,  test loss 1.402991, test error 41.90
# Epoch    26, train loss 0.259270, train error 7.68,  test loss 1.403426, test error 41.30
# Epoch    27, train loss 0.241867, train error 6.68,  test loss 1.431733, test error 42.40
# Epoch    28, train loss 0.237075, train error 6.78,  test loss 1.460698, test error 41.30
# Epoch    29, train loss 0.224548, train error 6.05,  test loss 1.475735, test error 42.20
# Epoch    30, train loss 0.205997, train error 5.10,  test loss 1.510122, test error 41.80
# Epoch    31, train loss 0.201702, train error 4.97,  test loss 1.496336, test error 41.60
# Epoch    32, train loss 0.196609, train error 4.95,  test loss 1.539198, test error 41.70
# Epoch    33, train loss 0.191717, train error 4.70,  test loss 1.534499, test error 41.80
# Epoch    34, train loss 0.187481, train error 4.65,  test loss 1.569358, test error 41.00
# Epoch    35, train loss 0.181411, train error 4.55,  test loss 1.570657, test error 41.50
# Epoch    36, train loss 0.176040, train error 4.25,  test loss 1.575780, test error 41.20
# Epoch    37, train loss 0.171857, train error 3.82,  test loss 1.590127, test error 41.20
# Epoch    38, train loss 0.168079, train error 3.75,  test loss 1.618111, test error 40.60
# Epoch    39, train loss 0.162614, train error 3.82,  test loss 1.626811, test error 40.60
# Epoch    40, train loss 0.157913, train error 3.40,  test loss 1.635535, test error 40.60
# Epoch    41, train loss 0.155713, train error 3.50,  test loss 1.641498, test error 40.90
# Epoch    42, train loss 0.154211, train error 3.35,  test loss 1.650020, test error 40.20
# Epoch    43, train loss 0.151695, train error 3.32,  test loss 1.652876, test error 40.90
# Epoch    44, train loss 0.149295, train error 3.22,  test loss 1.661459, test error 41.00
# Epoch    45, train loss 0.148120, train error 3.10,  test loss 1.680888, test error 40.70
# Epoch    46, train loss 0.145698, train error 3.05,  test loss 1.680575, test error 40.70
# Epoch    47, train loss 0.144116, train error 3.05,  test loss 1.691280, test error 40.80
# Epoch    48, train loss 0.142454, train error 2.72,  test loss 1.703854, test error 41.40
# Epoch    49, train loss 0.140048, train error 2.97,  test loss 1.701461, test error 40.60
# Epoch    50, train loss 0.138492, train error 2.70,  test loss 1.705565, test error 41.00
# Epoch    51, train loss 0.137318, train error 2.72,  test loss 1.710379, test error 40.30
# Epoch    52, train loss 0.136875, train error 2.68,  test loss 1.718489, test error 40.80
# Epoch    53, train loss 0.135704, train error 2.62,  test loss 1.716048, test error 40.80
# Epoch    54, train loss 0.135374, train error 2.55,  test loss 1.720905, test error 40.80
# Epoch    55, train loss 0.133978, train error 2.53,  test loss 1.727727, test error 41.00
# Epoch    56, train loss 0.133377, train error 2.45,  test loss 1.735825, test error 41.00
# Epoch    57, train loss 0.132167, train error 2.43,  test loss 1.737617, test error 41.30
# Epoch    58, train loss 0.131210, train error 2.40,  test loss 1.739618, test error 40.70
# Epoch    59, train loss 0.130419, train error 2.40,  test loss 1.746471, test error 40.70
# Epoch    60, train loss 0.129894, train error 2.43,  test loss 1.748087, test error 41.00
# Epoch    61, train loss 0.129390, train error 2.40,  test loss 1.749741, test error 41.00
# Epoch    62, train loss 0.128926, train error 2.38,  test loss 1.750901, test error 40.90
# Epoch    63, train loss 0.128491, train error 2.25,  test loss 1.752352, test error 40.90
# Epoch    64, train loss 0.128078, train error 2.30,  test loss 1.755144, test error 41.10
# Epoch    65, train loss 0.127665, train error 2.22,  test loss 1.757025, test error 40.60
# Epoch    66, train loss 0.127291, train error 2.38,  test loss 1.759008, test error 41.00
# Epoch    67, train loss 0.126886, train error 2.22,  test loss 1.759930, test error 40.70
# Epoch    68, train loss 0.126465, train error 2.18,  test loss 1.764940, test error 41.10
# Epoch    69, train loss 0.126034, train error 2.18,  test loss 1.765107, test error 41.00
# Epoch    70, train loss 0.125766, train error 2.20,  test loss 1.766955, test error 41.00
# Epoch    71, train loss 0.125545, train error 2.18,  test loss 1.768280, test error 41.10
# Epoch    72, train loss 0.125319, train error 2.12,  test loss 1.768710, test error 41.00
# Epoch    73, train loss 0.125125, train error 2.10,  test loss 1.769842, test error 41.10
# Epoch    74, train loss 0.124927, train error 2.10,  test loss 1.771284, test error 40.90
# Epoch    75, train loss 0.124717, train error 2.10,  test loss 1.772520, test error 40.80
# Epoch    76, train loss 0.124528, train error 2.12,  test loss 1.773186, test error 41.30
# Epoch    77, train loss 0.124321, train error 2.12,  test loss 1.774419, test error 41.00
# Epoch    78, train loss 0.124115, train error 2.15,  test loss 1.775501, test error 41.00
# Epoch    79, train loss 0.123926, train error 2.10,  test loss 1.774957, test error 41.00
# Epoch    80, train loss 0.123805, train error 2.10,  test loss 1.775978, test error 40.90
# Epoch    81, train loss 0.123698, train error 2.12,  test loss 1.777019, test error 41.00
# Epoch    82, train loss 0.123593, train error 2.15,  test loss 1.777868, test error 40.90
# Epoch    83, train loss 0.123496, train error 2.10,  test loss 1.778302, test error 40.90
# Epoch    84, train loss 0.123392, train error 2.15,  test loss 1.779019, test error 40.90
# Epoch    85, train loss 0.123296, train error 2.10,  test loss 1.779755, test error 40.90
# Epoch    86, train loss 0.123192, train error 2.10,  test loss 1.780065, test error 41.00
# Epoch    87, train loss 0.123091, train error 2.12,  test loss 1.780061, test error 41.00
# Epoch    88, train loss 0.122998, train error 2.12,  test loss 1.780555, test error 40.90
# Epoch    89, train loss 0.122895, train error 2.10,  test loss 1.781454, test error 40.90
# Epoch    90, train loss 0.122840, train error 2.10,  test loss 1.781513, test error 41.00
# Epoch    91, train loss 0.122789, train error 2.10,  test loss 1.781843, test error 40.90
# Epoch    92, train loss 0.122736, train error 2.12,  test loss 1.782131, test error 40.90
# Epoch    93, train loss 0.122687, train error 2.10,  test loss 1.782687, test error 41.00
# Epoch    94, train loss 0.122638, train error 2.07,  test loss 1.782736, test error 41.00
# Epoch    95, train loss 0.122589, train error 2.10,  test loss 1.782866, test error 40.90
# Epoch    96, train loss 0.122538, train error 2.10,  test loss 1.783172, test error 40.90
# Epoch    97, train loss 0.122489, train error 2.10,  test loss 1.783570, test error 40.90
# Epoch    98, train loss 0.122441, train error 2.12,  test loss 1.783960, test error 40.90
# Epoch    99, train loss 0.122389, train error 2.12,  test loss 1.784271, test error 40.90

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
