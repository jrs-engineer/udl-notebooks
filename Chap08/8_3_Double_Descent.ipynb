# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302059, train error 89.60,  test loss 2.302663, test error 89.90
# Epoch   100, train loss 1.879579, train error 71.55,  test loss 1.739912, test error 68.88
# Epoch   200, train loss 1.863938, train error 69.75,  test loss 1.713381, test error 68.12
# Epoch   300, train loss 1.868889, train error 70.28,  test loss 1.721447, test error 68.82
# Epoch   400, train loss 1.862074, train error 69.70,  test loss 1.711562, test error 68.68
# Epoch   500, train loss 1.860074, train error 70.65,  test loss 1.707443, test error 69.00
# Epoch   600, train loss 1.860621, train error 70.43,  test loss 1.706557, test error 68.50
# Epoch   700, train loss 1.860236, train error 70.05,  test loss 1.707536, test error 68.47
# Epoch   800, train loss 1.867000, train error 70.40,  test loss 1.707852, test error 68.97
# Epoch   900, train loss 1.864887, train error 69.72,  test loss 1.716853, test error 67.95
# Training model with   4 hidden variables
# Epoch     0, train loss 2.283787, train error 85.12,  test loss 2.287936, test error 86.38
# Epoch   100, train loss 1.793194, train error 66.05,  test loss 1.663720, test error 65.65
# Epoch   200, train loss 1.773246, train error 65.60,  test loss 1.647645, test error 65.18
# Epoch   300, train loss 1.768232, train error 65.97,  test loss 1.653497, test error 64.70
# Epoch   400, train loss 1.768486, train error 65.68,  test loss 1.653077, test error 64.65
# Epoch   500, train loss 1.761206, train error 65.90,  test loss 1.645080, test error 64.35
# Epoch   600, train loss 1.768789, train error 66.00,  test loss 1.662818, test error 65.20
# Epoch   700, train loss 1.763355, train error 65.90,  test loss 1.654959, test error 65.40
# Epoch   800, train loss 1.761054, train error 66.00,  test loss 1.654280, test error 65.07
# Epoch   900, train loss 1.759681, train error 65.15,  test loss 1.658417, test error 64.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.260034, train error 84.65,  test loss 2.246699, test error 83.82
# Epoch   100, train loss 1.725966, train error 63.35,  test loss 1.577699, test error 60.92
# Epoch   200, train loss 1.678691, train error 61.03,  test loss 1.543928, test error 58.97
# Epoch   300, train loss 1.666096, train error 61.05,  test loss 1.536354, test error 58.97
# Epoch   400, train loss 1.663866, train error 60.65,  test loss 1.546500, test error 60.05
# Epoch   500, train loss 1.656883, train error 60.55,  test loss 1.547576, test error 59.35
# Epoch   600, train loss 1.654836, train error 59.83,  test loss 1.556514, test error 59.58
# Epoch   700, train loss 1.649178, train error 59.95,  test loss 1.544242, test error 59.70
# Epoch   800, train loss 1.645730, train error 59.30,  test loss 1.554658, test error 59.75
# Epoch   900, train loss 1.644718, train error 58.80,  test loss 1.558151, test error 59.67
# Training model with   8 hidden variables
# Epoch     0, train loss 2.251764, train error 83.75,  test loss 2.247606, test error 83.50
# Epoch   100, train loss 1.602735, train error 56.70,  test loss 1.447359, test error 56.30
# Epoch   200, train loss 1.556795, train error 55.83,  test loss 1.414660, test error 53.72
# Epoch   300, train loss 1.529256, train error 54.05,  test loss 1.384314, test error 53.40
# Epoch   400, train loss 1.517446, train error 54.25,  test loss 1.384199, test error 52.97
# Epoch   500, train loss 1.509762, train error 53.55,  test loss 1.389929, test error 52.97
# Epoch   600, train loss 1.508367, train error 53.38,  test loss 1.392802, test error 52.58
# Epoch   700, train loss 1.501359, train error 53.22,  test loss 1.405993, test error 52.95
# Epoch   800, train loss 1.499865, train error 52.95,  test loss 1.406035, test error 53.22
# Epoch   900, train loss 1.499595, train error 53.28,  test loss 1.400172, test error 53.05
# Training model with  10 hidden variables
# Epoch     0, train loss 2.215001, train error 83.30,  test loss 2.179679, test error 82.22
# Epoch   100, train loss 1.551991, train error 54.25,  test loss 1.393282, test error 51.65
# Epoch   200, train loss 1.484783, train error 51.33,  test loss 1.363717, test error 51.25
# Epoch   300, train loss 1.460763, train error 50.67,  test loss 1.353897, test error 49.55
# Epoch   400, train loss 1.459635, train error 50.38,  test loss 1.363307, test error 50.38
# Epoch   500, train loss 1.440070, train error 49.03,  test loss 1.359632, test error 49.53
# Epoch   600, train loss 1.432111, train error 48.95,  test loss 1.365084, test error 49.35
# Epoch   700, train loss 1.426074, train error 49.08,  test loss 1.376962, test error 49.97
# Epoch   800, train loss 1.423841, train error 48.55,  test loss 1.383529, test error 49.60
# Epoch   900, train loss 1.425797, train error 49.35,  test loss 1.395584, test error 50.03
# Training model with  14 hidden variables
# Epoch     0, train loss 2.162273, train error 81.68,  test loss 2.120344, test error 80.57
# Epoch   100, train loss 1.494423, train error 52.60,  test loss 1.440880, test error 55.62
# Epoch   200, train loss 1.439996, train error 51.10,  test loss 1.464693, test error 55.35
# Epoch   300, train loss 1.407205, train error 50.20,  test loss 1.495504, test error 55.10
# Epoch   400, train loss 1.391223, train error 49.05,  test loss 1.509413, test error 55.45
# Epoch   500, train loss 1.382104, train error 48.80,  test loss 1.527583, test error 55.45
# Epoch   600, train loss 1.381326, train error 48.70,  test loss 1.551110, test error 56.12
# Epoch   700, train loss 1.364813, train error 47.85,  test loss 1.545470, test error 56.35
# Epoch   800, train loss 1.355424, train error 47.60,  test loss 1.570670, test error 55.90
# Epoch   900, train loss 1.356365, train error 47.83,  test loss 1.587570, test error 55.17
# Training model with  18 hidden variables
# Epoch     0, train loss 2.138030, train error 79.05,  test loss 2.097070, test error 76.57
# Epoch   100, train loss 1.337201, train error 44.17,  test loss 1.235187, test error 45.40
# Epoch   200, train loss 1.255507, train error 41.40,  test loss 1.264940, test error 46.85
# Epoch   300, train loss 1.211211, train error 39.97,  test loss 1.324355, test error 47.95
# Epoch   400, train loss 1.182989, train error 38.80,  test loss 1.359565, test error 48.58
# Epoch   500, train loss 1.167246, train error 38.47,  test loss 1.412787, test error 49.00
# Epoch   600, train loss 1.167395, train error 38.10,  test loss 1.454064, test error 48.78
# Epoch   700, train loss 1.144182, train error 38.12,  test loss 1.522367, test error 49.55
# Epoch   800, train loss 1.130128, train error 37.60,  test loss 1.547977, test error 49.58
# Epoch   900, train loss 1.120187, train error 37.20,  test loss 1.601065, test error 50.25
# Training model with  22 hidden variables
# Epoch     0, train loss 2.183397, train error 81.38,  test loss 2.169454, test error 80.55
# Epoch   100, train loss 1.268281, train error 42.55,  test loss 1.263256, test error 46.67
# Epoch   200, train loss 1.146567, train error 38.78,  test loss 1.322918, test error 47.22
# Epoch   300, train loss 1.071460, train error 36.05,  test loss 1.421749, test error 48.53
# Epoch   400, train loss 1.047835, train error 34.93,  test loss 1.521104, test error 49.20
# Epoch   500, train loss 1.005839, train error 33.53,  test loss 1.601284, test error 50.33
# Epoch   600, train loss 0.997612, train error 33.35,  test loss 1.635749, test error 49.83
# Epoch   700, train loss 0.981390, train error 32.93,  test loss 1.686487, test error 50.83
# Epoch   800, train loss 0.990886, train error 33.50,  test loss 1.733850, test error 51.85
# Epoch   900, train loss 0.969245, train error 32.88,  test loss 1.752362, test error 51.62
# Training model with  26 hidden variables
# Epoch     0, train loss 2.212975, train error 81.70,  test loss 2.227789, test error 81.78
# Epoch   100, train loss 1.194923, train error 38.92,  test loss 1.341974, test error 49.62
# Epoch   200, train loss 1.056698, train error 35.72,  test loss 1.471329, test error 50.00
# Epoch   300, train loss 0.970764, train error 32.80,  test loss 1.590335, test error 52.60
# Epoch   400, train loss 0.927138, train error 31.32,  test loss 1.703280, test error 52.90
# Epoch   500, train loss 0.898254, train error 30.85,  test loss 1.780626, test error 53.40
# Epoch   600, train loss 0.877948, train error 29.88,  test loss 1.867939, test error 53.80
# Epoch   700, train loss 0.860641, train error 29.45,  test loss 1.938586, test error 53.03
# Epoch   800, train loss 0.847454, train error 28.75,  test loss 2.032971, test error 53.53
# Epoch   900, train loss 0.841080, train error 28.30,  test loss 2.108791, test error 54.08
# Training model with  30 hidden variables
# Epoch     0, train loss 2.148750, train error 79.88,  test loss 2.112517, test error 78.38
# Epoch   100, train loss 1.107087, train error 35.95,  test loss 1.409441, test error 51.15
# Epoch   200, train loss 0.940655, train error 30.85,  test loss 1.568197, test error 52.55
# Epoch   300, train loss 0.848083, train error 28.62,  test loss 1.780458, test error 52.12
# Epoch   400, train loss 0.788820, train error 25.65,  test loss 1.957425, test error 52.90
# Epoch   500, train loss 0.749105, train error 24.57,  test loss 2.133070, test error 53.65
# Epoch   600, train loss 0.737242, train error 24.43,  test loss 2.240160, test error 54.25
# Epoch   700, train loss 0.711810, train error 23.93,  test loss 2.389952, test error 54.78
# Epoch   800, train loss 0.688731, train error 23.22,  test loss 2.507648, test error 55.17
# Epoch   900, train loss 0.676451, train error 22.85,  test loss 2.611816, test error 54.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.139904, train error 79.38,  test loss 2.119140, test error 80.10
# Epoch   100, train loss 1.018588, train error 34.93,  test loss 1.393305, test error 49.70
# Epoch   200, train loss 0.768635, train error 25.43,  test loss 1.684157, test error 50.53
# Epoch   300, train loss 0.649875, train error 21.60,  test loss 2.053109, test error 52.42
# Epoch   400, train loss 0.586189, train error 19.55,  test loss 2.371223, test error 53.10
# Epoch   500, train loss 0.570362, train error 19.53,  test loss 2.734462, test error 54.60
# Epoch   600, train loss 0.527460, train error 17.93,  test loss 3.051964, test error 56.12
# Epoch   700, train loss 0.482545, train error 16.47,  test loss 3.291540, test error 55.40
# Epoch   800, train loss 0.474495, train error 16.78,  test loss 3.530887, test error 55.88
# Epoch   900, train loss 0.447568, train error 15.55,  test loss 3.687595, test error 55.25
# Training model with  40 hidden variables
# Epoch     0, train loss 2.127692, train error 77.00,  test loss 2.110525, test error 76.75
# Epoch   100, train loss 0.950540, train error 30.80,  test loss 1.460866, test error 51.30
# Epoch   200, train loss 0.668312, train error 22.12,  test loss 1.905894, test error 53.10
# Epoch   300, train loss 0.559239, train error 19.38,  test loss 2.626301, test error 56.55
# Epoch   400, train loss 0.442142, train error 15.57,  test loss 3.343977, test error 57.03
# Epoch   500, train loss 0.351702, train error 11.53,  test loss 3.931209, test error 57.00
# Epoch   600, train loss 0.289085, train error 9.53,  test loss 4.648718, test error 57.22
# Epoch   700, train loss 0.300096, train error 10.50,  test loss 5.501284, test error 58.22
# Epoch   800, train loss 0.258098, train error 9.20,  test loss 6.220829, test error 58.10
# Epoch   900, train loss 0.263560, train error 9.70,  test loss 6.579108, test error 57.78
# Training model with  45 hidden variables
# Epoch     0, train loss 2.073479, train error 78.30,  test loss 2.025468, test error 78.72
# Epoch   100, train loss 0.823581, train error 26.22,  test loss 1.464137, test error 49.22
# Epoch   200, train loss 0.487368, train error 14.53,  test loss 2.173129, test error 52.80
# Epoch   300, train loss 0.315523, train error 9.07,  test loss 3.199321, test error 54.95
# Epoch   400, train loss 0.228402, train error 7.25,  test loss 4.472803, test error 55.03
# Epoch   500, train loss 0.155200, train error 5.18,  test loss 5.775044, test error 55.83
# Epoch   600, train loss 0.108728, train error 3.25,  test loss 7.068594, test error 56.22
# Epoch   700, train loss 0.014465, train error 0.00,  test loss 8.132086, test error 56.70
# Epoch   800, train loss 0.009638, train error 0.00,  test loss 8.855283, test error 57.15
# Epoch   900, train loss 0.007164, train error 0.00,  test loss 9.397166, test error 57.10
# Training model with  50 hidden variables
# Epoch     0, train loss 2.107485, train error 76.95,  test loss 2.052325, test error 75.68
# Epoch   100, train loss 0.722418, train error 22.80,  test loss 1.506786, test error 48.50
# Epoch   200, train loss 0.345554, train error 9.75,  test loss 2.527852, test error 53.08
# Epoch   300, train loss 0.165395, train error 4.18,  test loss 3.894301, test error 55.03
# Epoch   400, train loss 0.044595, train error 0.20,  test loss 5.432425, test error 55.60
# Epoch   500, train loss 0.015403, train error 0.00,  test loss 6.475203, test error 55.95
# Epoch   600, train loss 0.009588, train error 0.00,  test loss 7.144224, test error 56.17
# Epoch   700, train loss 0.006694, train error 0.00,  test loss 7.614676, test error 56.33
# Epoch   800, train loss 0.005091, train error 0.00,  test loss 7.995893, test error 56.42
# Epoch   900, train loss 0.004121, train error 0.00,  test loss 8.316986, test error 56.62
# Training model with  55 hidden variables
# Epoch     0, train loss 2.030113, train error 75.53,  test loss 1.968051, test error 75.00
# Epoch   100, train loss 0.612774, train error 18.75,  test loss 1.634905, test error 51.08
# Epoch   200, train loss 0.176409, train error 3.12,  test loss 2.977485, test error 53.70
# Epoch   300, train loss 0.032011, train error 0.00,  test loss 4.617918, test error 54.95
# Epoch   400, train loss 0.012911, train error 0.00,  test loss 5.491193, test error 55.12
# Epoch   500, train loss 0.007727, train error 0.00,  test loss 6.065972, test error 55.38
# Epoch   600, train loss 0.005386, train error 0.00,  test loss 6.467056, test error 55.65
# Epoch   700, train loss 0.004087, train error 0.00,  test loss 6.782641, test error 55.47
# Epoch   800, train loss 0.003248, train error 0.00,  test loss 7.045026, test error 55.45
# Epoch   900, train loss 0.002681, train error 0.00,  test loss 7.264017, test error 55.53
# Training model with  60 hidden variables
# Epoch     0, train loss 2.051981, train error 76.90,  test loss 1.991895, test error 76.28
# Epoch   100, train loss 0.516394, train error 14.72,  test loss 1.792341, test error 50.72
# Epoch   200, train loss 0.093855, train error 0.75,  test loss 3.495283, test error 53.50
# Epoch   300, train loss 0.018436, train error 0.00,  test loss 4.771896, test error 54.28
# Epoch   400, train loss 0.009047, train error 0.00,  test loss 5.445658, test error 54.28
# Epoch   500, train loss 0.005779, train error 0.00,  test loss 5.879238, test error 54.25
# Epoch   600, train loss 0.004196, train error 0.00,  test loss 6.207550, test error 54.42
# Epoch   700, train loss 0.003220, train error 0.00,  test loss 6.474029, test error 54.55
# Epoch   800, train loss 0.002599, train error 0.00,  test loss 6.686810, test error 54.62
# Epoch   900, train loss 0.002172, train error 0.00,  test loss 6.871855, test error 54.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.097798, train error 78.70,  test loss 2.058943, test error 78.07
# Epoch   100, train loss 0.398059, train error 10.32,  test loss 1.897114, test error 51.10
# Epoch   200, train loss 0.034846, train error 0.00,  test loss 3.631871, test error 54.30
# Epoch   300, train loss 0.011190, train error 0.00,  test loss 4.463430, test error 54.33
# Epoch   400, train loss 0.006266, train error 0.00,  test loss 4.922812, test error 54.45
# Epoch   500, train loss 0.004188, train error 0.00,  test loss 5.228760, test error 54.47
# Epoch   600, train loss 0.003109, train error 0.00,  test loss 5.466687, test error 54.35
# Epoch   700, train loss 0.002430, train error 0.00,  test loss 5.654595, test error 54.50
# Epoch   800, train loss 0.001982, train error 0.00,  test loss 5.816397, test error 54.40
# Epoch   900, train loss 0.001666, train error 0.00,  test loss 5.953982, test error 54.50
# Training model with  80 hidden variables
# Epoch     0, train loss 2.006947, train error 74.53,  test loss 1.947567, test error 75.00
# Epoch   100, train loss 0.230069, train error 3.82,  test loss 2.046679, test error 50.65
# Epoch   200, train loss 0.019756, train error 0.00,  test loss 3.368789, test error 51.72
# Epoch   300, train loss 0.007989, train error 0.00,  test loss 3.909906, test error 51.80
# Epoch   400, train loss 0.004702, train error 0.00,  test loss 4.210110, test error 51.53
# Epoch   500, train loss 0.003243, train error 0.00,  test loss 4.440044, test error 51.85
# Epoch   600, train loss 0.002438, train error 0.00,  test loss 4.614774, test error 51.85
# Epoch   700, train loss 0.001937, train error 0.00,  test loss 4.758265, test error 51.97
# Epoch   800, train loss 0.001593, train error 0.00,  test loss 4.877311, test error 52.08
# Epoch   900, train loss 0.001348, train error 0.00,  test loss 4.981546, test error 52.03
# Training model with  90 hidden variables
# Epoch     0, train loss 2.011346, train error 74.53,  test loss 1.973137, test error 75.35
# Epoch   100, train loss 0.164526, train error 2.12,  test loss 2.156773, test error 50.95
# Epoch   200, train loss 0.015196, train error 0.00,  test loss 3.169987, test error 51.00
# Epoch   300, train loss 0.006619, train error 0.00,  test loss 3.601757, test error 51.03
# Epoch   400, train loss 0.004036, train error 0.00,  test loss 3.866305, test error 51.25
# Epoch   500, train loss 0.002824, train error 0.00,  test loss 4.056163, test error 51.25
# Epoch   600, train loss 0.002142, train error 0.00,  test loss 4.203940, test error 51.10
# Epoch   700, train loss 0.001710, train error 0.00,  test loss 4.323570, test error 51.17
# Epoch   800, train loss 0.001416, train error 0.00,  test loss 4.425825, test error 51.28
# Epoch   900, train loss 0.001201, train error 0.00,  test loss 4.513412, test error 51.42
# Training model with 100 hidden variables
# Epoch     0, train loss 1.971750, train error 72.40,  test loss 1.897945, test error 73.32
# Epoch   100, train loss 0.091795, train error 0.45,  test loss 2.307252, test error 51.20
# Epoch   200, train loss 0.011765, train error 0.00,  test loss 3.160228, test error 51.67
# Epoch   300, train loss 0.005525, train error 0.00,  test loss 3.538640, test error 52.12
# Epoch   400, train loss 0.003462, train error 0.00,  test loss 3.767295, test error 52.10
# Epoch   500, train loss 0.002465, train error 0.00,  test loss 3.938234, test error 52.15
# Epoch   600, train loss 0.001891, train error 0.00,  test loss 4.071486, test error 52.08
# Epoch   700, train loss 0.001520, train error 0.00,  test loss 4.180409, test error 52.15
# Epoch   800, train loss 0.001263, train error 0.00,  test loss 4.273861, test error 52.20
# Epoch   900, train loss 0.001076, train error 0.00,  test loss 4.353240, test error 52.25
# Training model with 120 hidden variables
# Epoch     0, train loss 1.974429, train error 72.97,  test loss 1.910983, test error 73.57
# Epoch   100, train loss 0.049538, train error 0.00,  test loss 2.266990, test error 51.00
# Epoch   200, train loss 0.009444, train error 0.00,  test loss 2.895638, test error 51.42
# Epoch   300, train loss 0.004669, train error 0.00,  test loss 3.181473, test error 51.33
# Epoch   400, train loss 0.002991, train error 0.00,  test loss 3.366691, test error 51.17
# Epoch   500, train loss 0.002159, train error 0.00,  test loss 3.502959, test error 51.28
# Epoch   600, train loss 0.001668, train error 0.00,  test loss 3.608989, test error 51.30
# Epoch   700, train loss 0.001349, train error 0.00,  test loss 3.698148, test error 51.17
# Epoch   800, train loss 0.001126, train error 0.00,  test loss 3.773337, test error 51.20
# Epoch   900, train loss 0.000962, train error 0.00,  test loss 3.839166, test error 51.22
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959684, train error 72.22,  test loss 1.872951, test error 72.47
# Epoch   100, train loss 0.035089, train error 0.00,  test loss 2.121834, test error 49.47
# Epoch   200, train loss 0.008002, train error 0.00,  test loss 2.601655, test error 49.58
# Epoch   300, train loss 0.004128, train error 0.00,  test loss 2.828537, test error 49.67
# Epoch   400, train loss 0.002682, train error 0.00,  test loss 2.975457, test error 49.53
# Epoch   500, train loss 0.001953, train error 0.00,  test loss 3.086136, test error 49.53
# Epoch   600, train loss 0.001519, train error 0.00,  test loss 3.175252, test error 49.62
# Epoch   700, train loss 0.001234, train error 0.00,  test loss 3.248075, test error 49.65
# Epoch   800, train loss 0.001034, train error 0.00,  test loss 3.310667, test error 49.62
# Epoch   900, train loss 0.000886, train error 0.00,  test loss 3.364440, test error 49.70
# Training model with 160 hidden variables
# Epoch     0, train loss 1.944236, train error 72.40,  test loss 1.871343, test error 72.22
# Epoch   100, train loss 0.028999, train error 0.00,  test loss 2.072624, test error 48.80
# Epoch   200, train loss 0.007330, train error 0.00,  test loss 2.460492, test error 48.67
# Epoch   300, train loss 0.003849, train error 0.00,  test loss 2.650925, test error 48.62
# Epoch   400, train loss 0.002531, train error 0.00,  test loss 2.778455, test error 48.62
# Epoch   500, train loss 0.001854, train error 0.00,  test loss 2.875113, test error 48.75
# Epoch   600, train loss 0.001449, train error 0.00,  test loss 2.952360, test error 48.70
# Epoch   700, train loss 0.001180, train error 0.00,  test loss 3.016628, test error 48.78
# Epoch   800, train loss 0.000991, train error 0.00,  test loss 3.070727, test error 48.80
# Epoch   900, train loss 0.000851, train error 0.00,  test loss 3.119023, test error 48.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.906425, train error 69.60,  test loss 1.834436, test error 71.05
# Epoch   100, train loss 0.024319, train error 0.00,  test loss 2.137385, test error 50.10
# Epoch   200, train loss 0.006586, train error 0.00,  test loss 2.498626, test error 49.75
# Epoch   300, train loss 0.003529, train error 0.00,  test loss 2.679874, test error 49.72
# Epoch   400, train loss 0.002340, train error 0.00,  test loss 2.803693, test error 49.75
# Epoch   500, train loss 0.001722, train error 0.00,  test loss 2.895647, test error 49.70
# Epoch   600, train loss 0.001349, train error 0.00,  test loss 2.968622, test error 49.65
# Epoch   700, train loss 0.001101, train error 0.00,  test loss 3.029757, test error 49.70
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 3.083179, test error 49.80
# Epoch   900, train loss 0.000796, train error 0.00,  test loss 3.129212, test error 49.70
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918359, train error 71.57,  test loss 1.842231, test error 71.75
# Epoch   100, train loss 0.022091, train error 0.00,  test loss 1.941464, test error 46.70
# Epoch   200, train loss 0.006264, train error 0.00,  test loss 2.240795, test error 46.78
# Epoch   300, train loss 0.003396, train error 0.00,  test loss 2.393371, test error 46.80
# Epoch   400, train loss 0.002262, train error 0.00,  test loss 2.496882, test error 46.62
# Epoch   500, train loss 0.001669, train error 0.00,  test loss 2.575213, test error 46.65
# Epoch   600, train loss 0.001310, train error 0.00,  test loss 2.638521, test error 46.65
# Epoch   700, train loss 0.001071, train error 0.00,  test loss 2.690541, test error 46.62
# Epoch   800, train loss 0.000902, train error 0.00,  test loss 2.735479, test error 46.65
# Epoch   900, train loss 0.000776, train error 0.00,  test loss 2.774623, test error 46.67
# Training model with 250 hidden variables
# Epoch     0, train loss 1.896527, train error 69.40,  test loss 1.821108, test error 70.75
# Epoch   100, train loss 0.017420, train error 0.00,  test loss 1.963308, test error 48.62
# Epoch   200, train loss 0.005366, train error 0.00,  test loss 2.228194, test error 48.53
# Epoch   300, train loss 0.002985, train error 0.00,  test loss 2.369624, test error 48.53
# Epoch   400, train loss 0.002015, train error 0.00,  test loss 2.466925, test error 48.33
# Epoch   500, train loss 0.001500, train error 0.00,  test loss 2.540755, test error 48.38
# Epoch   600, train loss 0.001183, train error 0.00,  test loss 2.599608, test error 48.40
# Epoch   700, train loss 0.000971, train error 0.00,  test loss 2.648800, test error 48.40
# Epoch   800, train loss 0.000820, train error 0.00,  test loss 2.691676, test error 48.38
# Epoch   900, train loss 0.000707, train error 0.00,  test loss 2.728824, test error 48.40
# Training model with 300 hidden variables
# Epoch     0, train loss 1.883144, train error 68.07,  test loss 1.821585, test error 70.20
# Epoch   100, train loss 0.014239, train error 0.00,  test loss 1.927897, test error 48.22
# Epoch   200, train loss 0.004765, train error 0.00,  test loss 2.158251, test error 48.25
# Epoch   300, train loss 0.002710, train error 0.00,  test loss 2.283752, test error 48.15
# Epoch   400, train loss 0.001842, train error 0.00,  test loss 2.369029, test error 48.10
# Epoch   500, train loss 0.001379, train error 0.00,  test loss 2.433936, test error 48.05
# Epoch   600, train loss 0.001093, train error 0.00,  test loss 2.486655, test error 48.00
# Epoch   700, train loss 0.000900, train error 0.00,  test loss 2.530837, test error 48.05
# Epoch   800, train loss 0.000761, train error 0.00,  test loss 2.568979, test error 47.92
# Epoch   900, train loss 0.000658, train error 0.00,  test loss 2.602265, test error 47.95
# Training model with 400 hidden variables
# Epoch     0, train loss 1.878249, train error 68.03,  test loss 1.842204, test error 70.47
# Epoch   100, train loss 0.011725, train error 0.00,  test loss 1.752902, test error 45.33
# Epoch   200, train loss 0.004175, train error 0.00,  test loss 1.931477, test error 45.35
# Epoch   300, train loss 0.002415, train error 0.00,  test loss 2.027932, test error 45.05
# Epoch   400, train loss 0.001663, train error 0.00,  test loss 2.095957, test error 44.97
# Epoch   500, train loss 0.001252, train error 0.00,  test loss 2.147961, test error 44.92
# Epoch   600, train loss 0.000996, train error 0.00,  test loss 2.190035, test error 44.95
# Epoch   700, train loss 0.000823, train error 0.00,  test loss 2.225234, test error 44.85
# Epoch   800, train loss 0.000699, train error 0.00,  test loss 2.255756, test error 44.80
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.282879, test error 44.92

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
